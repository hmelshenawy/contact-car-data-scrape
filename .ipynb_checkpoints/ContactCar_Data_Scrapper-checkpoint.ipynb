# %%
from bs4 import BeautifulSoup as bs
import requests
import re
import pandas as pd
from time import sleep
from selenium.webdriver.common.by import By

import http.client  # or http.client if you're on Python 3
http.client._MAXHEADERS = 10000

import warnings 
warnings.filterwarnings(action= 'ignore')

import datetime
# Out:
# /Users/haitham/opt/anaconda3/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.14) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# # Test

# %%
from selenium import webdriver

exec_path_mac = "/Users/haitham/Downloads/chromedriver_mac64 (1)/chromedriver" # Use This On MAC OS.
exec_paht_linux = "/home/haytham/Downloads/chromedriver_linux64/chromedriver" #Use This On LINUX.

main_link = "https://www.contactcars.com/en/cars/used/engines?page=1&sortOrder=false&sortBy=CreatedAt"

chrome = webdriver.Chrome(executable_path=exec_path_mac)

# chrome = webdriver.Firefox()

# %%
# from selenium import webdriver
# from selenium.webdriver.common.proxy import Proxy, ProxyType

# prox = Proxy()
# prox.proxy_type = ProxyType.MANUAL
# prox.http_proxy = "ip_addr:port"
# prox.socks_proxy = "ip_addr:port"
# prox.ssl_proxy = "ip_addr:port"
# prox.socks_version = 5

# capabilities = webdriver.DesiredCapabilities.CHROME
# prox.add_to_capabilities(capabilities)

# chrome = webdriver.Chrome(executable_path=exec_path_mac,desired_capabilities=capabilities)

# %%
def get_links_list(link, driver):
    
    driver.get(link)
    scroll_down(driver)
#     z = chrome.find_elements_by_css_selector("d-block bg--white car-link")
    z = driver.find_elements(by= By.CLASS_NAME,value="car-link")

    lnk_list = []

    for i in z:
#         print(i.get_attribute("href"))
        lnk_list.append(i.get_attribute("href"))

    return lnk_list



def scroll_down(driver):
    import time
    SCROLL_PAUSE_TIME = 1.7

# Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height



def get_ad_details(l):

    car_dict = {}
# l = "https://www.contactcars.com/en/car/626997664f4dc4c0a1d6a69f-Chevrolet-Optra-1.5-A-T-H-L?status=Used"
    chrome.get(l)
#     sleep(2.5)
    chrome.implicitly_wait(1)


    # car_details var list of WEBELEMENT include 
#     ['SUV','Body Shape','Automatic','Transmission','3,500 KM'
# ,'Mileage','Green','Color','1200 CC','Engine Capacity','Yes','Fabrica?']

    car_details = chrome.find_elements(by= By.CLASS_NAME,value="detail-cards")[-1].text.split("\n")
#     print(car_details)
    # car_info var like ['Opel', 'Mokka', '2022', 'Used', 'Egypt', '9 days ago', '855,000 EGP']
    car_info = chrome.find_elements(by= By.CLASS_NAME,value="used-car")[-1].text.split("\n")
#     print(car_info)

    
#     print(l.split("car/")[-1].split("-")[0])
    car_dict["Ad_ID"]= l
    
    car_dict.update(extract_details(car_details))
    

    car_dict["Condition"] = car_info[3]
    car_dict["Year"] = car_info[2]
    car_dict["brand"] = car_info[0]
    car_dict["Model"] = car_info[1]
    car_dict["date"] =  car_info[-2]
    car_dict["price"] = car_info[-1]
    
    print(car_dict)

    return car_dict


def get_page_link(nu):
    ma ="https://www.contactcars.com/en/cars/used/engines?page="
    ink = "&sortOrder=false&sortBy=CreatedAt"
    return ma+ str(nu) + ink


def get_brand_model(string):

    import math
    s = string.split(" ")[0:-1]

    model = " ".join( s[math.floor(len(s)/2) :])
    brand = " ".join( s[: math.floor(len(s)/2)])
#     print(brand, "\n", model,"\n_______")
    return brand, model

# def isFabrika(webElementList):
#     fabrika = False
#     for i in webElementList:
#         if i.text == 'Factory Paint':
# #             print("Fabrika")
#             fabrika= True
#         else:
#             fabrika= False
#     return fabrika


# def extract_details(mlist):

#     mdic = {}
#     i = 0
#     while i < len(mlist):
#         if (i % 2) == 0:
#             mdic[mlist[i+1]] = mlist[i]
#         i+=1
        
#     return mdic


# A FUNCTION TO GET THE DATE WHEN THE ADV PUPLISHED.
def correct_date(date_str):
    dtlist = date_str.split(" ")

    # if date_str like "20 days ago"(len == 3)
    if len(dtlist) == 3:
        days = int(dtlist[0])

        return (datetime.datetime.now().date() - datetime.timedelta( days )).strftime("%d-%m-%Y" )
    
    # if date str like "about 3 hours ago"(len == 4)
    elif len(dtlist) == 4:
        return datetime.datetime.now().date().strftime("%d-%m-%Y")

# %%
df = pd.DataFrame()

for i in range(1,75):
    
    if (i % 2) == 0:    #try to avoid scrape to be blocked by the website.
        sleep(5)

    links_list =  get_links_list(get_page_link(i), chrome)

    try:
        
        for link in links_list:
            
            try:
                print("____________________")
#                 print(link)

                car_dict = get_ad_details(link)

                df = df.append(car_dict, ignore_index = True)
                print(df.shape)
            except Exception as e2:
                print("inside exption")
#                 print(car_dict)
                print(e2)
                
                sleep(20)
                chrome = webdriver.Chrome(executable_path=exec_path_mac)   #trail to avoid being blocked
    
                continue
    
    except Exception as e:
        print("outer excption")
        print(e)
        continue
        
    
    print(df.tail(1))
    
print("End Of Data Scrape")
# Out:
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/jac/js4/5e14fbcc0536470cb01494145f8bfdd6', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '8,403 KM', 'Color': 'Red', 'Engine Capacity': '1500 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2022', 'brand': 'JAC', 'Model': 'JS4', 'date': 'about 16 hours ago', 'price': '530,000 EGP'}
# (1, 13)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/volkswagen/golf/16ca78db11a64a5f95b53e61bb6f8331', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '100 KM', 'Engine Capacity': '1200 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Volkswagen', 'Model': 'Golf', 'date': '9 days ago', 'price': '1,950,000 EGP'}
# (2, 13)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/eqs/06701e9061c042b48b9ca73317c5ee79', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '100 KM', 'Engine Capacity': '6400 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Mercedes', 'Model': 'EQS', 'date': '9 days ago', 'price': '5,200,000 EGP'}
# (3, 13)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/audi/a5/9551c6b0ece54461ae937d56a89be50e', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '100 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Audi', 'Model': 'A5', 'date': '9 days ago', 'price': '3,225,000 EGP'}
# (4, 13)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/byd/f3/3abaf9aecdeb48babc8a611b0c470c8b', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '14,397 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'BYD', 'Model': 'F3', 'date': '11 days ago', 'price': '330,000 EGP'}
# (5, 13)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/chevrolet/optra/dde1829d1e004b49a9d36f4fe35eef4a', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '38 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Chevrolet', 'Model': 'Optra', 'date': '11 days ago', 'price': '450,000 EGP'}
# (6, 13)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/430i', 'Body Shape': 'Cabriolet', 'Transmission': 'Dual Clutch', 'Mileage': '10 KM', 'Color': 'Gray', 'Engine Capacity': '2000 CC', 'Fabrica?': 'Yes', 'In Warranty': 'Yes', 'Condition': 'Used', 'Year': '2022', 'brand': 'BMW', 'Model': '430i Convertible', 'date': '12 days ago', 'price': '900,000 EGP'}
# (7, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/volvo/xc', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '16,000 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '2021', 'brand': 'Volvo', 'Model': 'XC 90', 'date': '2 months ago', 'price': '1,180,000 EGP'}
# (8, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/glc', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '12,600 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '2020', 'brand': 'Mercedes', 'Model': 'GLC 200', 'date': '4 days ago', 'price': '2,700,000 EGP'}
# (9, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/citroen/c5', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '40,000 KM', 'Color': 'Green', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2020', 'brand': 'Citroen', 'Model': 'C5 Aircross', 'date': '15 days ago', 'price': '288,000 EGP'}
# (10, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/glc', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '82,000 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '2020', 'brand': 'Mercedes', 'Model': 'GLC 300', 'date': 'about an hour ago', 'price': '2,400,000 EGP'}
# (11, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/toyota/corolla/fa8eb86bd44f42ca81772f9e4575c478', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '30,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2019', 'brand': 'Toyota', 'Model': 'Corolla', 'date': 'about an hour ago', 'price': '680,000 EGP'}
# (12, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/b150/8692bf6a1f3443aabc82d9a2216383d8', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '114,000 KM', 'Color': 'Gray', 'Engine Capacity': '1500 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2009', 'brand': 'Mercedes', 'Model': 'B150', 'date': 'about an hour ago', 'price': '385,000 EGP'}
# (13, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/skoda/octavia/6b2f96f2464a4f19a8057d976066f01f', 'Body Shape': 'Station', 'Transmission': 'Automatic', 'Mileage': '160,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2015', 'brand': 'Skoda', 'Model': 'Octavia', 'date': 'about an hour ago', 'price': '510,000 EGP'}
# (14, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/audi/q3/56b110daea764fcdb440536ca4323d61', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '140,000 KM', 'Engine Capacity': '1400 CC', 'Condition': 'Used', 'Year': '2016', 'brand': 'Audi', 'Model': 'Q3', 'date': 'about 2 hours ago', 'price': '750,000 EGP'}
# (15, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/audi/q3/35a8b7481ecf46b6b770c78fe07f0238', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '35,000 KM', 'Color': 'Dark Grey', 'Engine Capacity': '1400 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2021', 'brand': 'Audi', 'Model': 'Q3', 'date': 'about 2 hours ago', 'price': '1,200,000 EGP'}
# (16, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mitsubishi/lancer/07557b17cd7547eebf5d4d957121c5a0', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '180,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2009', 'brand': 'Mitsubishi', 'Model': 'Lancer', 'date': 'about 2 hours ago', 'price': '350,000 EGP'}
# (17, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/speranza/tiggo/760478e62fc64c77b48a1a552471bdc3', 'Body Shape': 'SUV', 'Transmission': 'Manual', 'Mileage': '125,000 KM', 'Color': 'Silver', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2013', 'brand': 'Speranza', 'Model': 'Tiggo', 'date': 'about 3 hours ago', 'price': '197,000 EGP'}
# (18, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/geely/emgrand', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '96,000 KM', 'Color': 'Maroon', 'Engine Capacity': '1500 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2015', 'brand': 'Geely', 'Model': 'Emgrand 7', 'date': 'about 3 hours ago', 'price': '190,000 EGP'}
# (19, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/seat/leon/3d50ed5749c44351a49124165002f8b6', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '112,000 KM', 'Engine Capacity': '1200 CC', 'Condition': 'Used', 'Year': '2015', 'brand': 'Seat', 'Model': 'Leon', 'date': 'about 3 hours ago', 'price': '445,000 EGP'}
# (20, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/kia/carens/255f7500fe6a47068c188eb45767acb3', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '160,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2011', 'brand': 'Kia', 'Model': 'Carens', 'date': 'about 5 hours ago', 'price': '350,000 EGP'}
# (21, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mg/zs/4da27a6b94ef4004ac79c150258a853c', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '1,000 KM', 'Color': 'White', 'Engine Capacity': '1500 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2022', 'brand': 'MG', 'Model': 'ZS', 'date': 'about 6 hours ago', 'price': '640,000 EGP'}
# (22, 14)
#                                                 Ad_ID Body Shape  Color  \
# 21  https://www.contactcars.com/en/usedcars/mg/zs/...        SUV  White
#
#    Condition Engine Capacity Fabrica?   Mileage Model Transmission  Year  \
# 21      Used         1500 CC      Yes  1,000 KM    ZS    Automatic  2022
#
#    brand               date        price In Warranty
# 21    MG  about 6 hours ago  640,000 EGP         NaN
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/m850i/b31503c4659d4f0db21db6f4d04870a6', 'Body Shape': 'Cabriolet', 'Transmission': 'Automatic', 'Mileage': '23,000 KM', 'Engine Capacity': '4400 CC', 'Condition': 'Used', 'Year': '2020', 'brand': 'BMW', 'Model': 'M850i', 'date': '5 days ago', 'price': '4,500,000 EGP'}
# (23, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/opel/grand', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '44,270 KM', 'Color': 'Maroon', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2021', 'brand': 'Opel', 'Model': 'Grand Land', 'date': '8 days ago', 'price': '930,000 EGP'}
# (24, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/volkswagen/tiguan/911c94081e574fccb5403a5678b924cf', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '100 KM', 'Engine Capacity': '1400 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Volkswagen', 'Model': 'Tiguan', 'date': '9 days ago', 'price': '1,730,000 EGP'}
# (25, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/nissan', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '44,566 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2020', 'brand': 'Nissan Motor Egypt', 'Model': 'Sunny', 'date': '11 days ago', 'price': '365,000 EGP'}
# (26, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/chery/arrizo', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '21,552 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'Chery', 'Model': 'ARRIZO 5', 'date': 'about a month ago', 'price': '395,000 EGP'}
# (27, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/nissan', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '179,394 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2015', 'brand': 'Nissan Motor Egypt', 'Model': 'Sunny', 'date': 'about a month ago', 'price': '260,000 EGP'}
# (28, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/m5/60f031ab7469413f8c99df36a6d7a4bc', 'Body Shape': 'Sedan', 'Transmission': 'Dual Clutch', 'Mileage': '10 KM', 'Color': 'Blue', 'Engine Capacity': '4400 CC', 'Fabrica?': 'Yes', 'In Warranty': 'Yes', 'Condition': 'Used', 'Year': '2022', 'brand': 'BMW', 'Model': 'M5', 'date': '12 days ago', 'price': '2,400,000 EGP'}
# (29, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/m8', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '10 KM', 'Color': 'Maroon', 'Engine Capacity': '4400 CC', 'Fabrica?': 'Yes', 'In Warranty': 'Yes', 'Condition': 'Used', 'Year': '2022', 'brand': 'BMW', 'Model': 'M8', 'date': '12 days ago', 'price': '3,000,000 EGP'}
# (30, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/volvo/xc', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '17,500 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'Volvo', 'Model': 'XC 60', 'date': '5 days ago', 'price': '1,950,000 EGP'}
# (31, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/toyota/corolla/36c4410927a243a782e578bf30fa5a92', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '37,000 KM', 'Color': 'Black', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2021', 'brand': 'Toyota', 'Model': 'Corolla', 'date': '8 days ago', 'price': '800,000 EGP'}
# (32, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mg/5/07875f7548a64b3dbcf6c01f582a7dcd', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '52,000 KM', 'Engine Capacity': '1500 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2021', 'brand': 'MG', 'Model': '5', 'date': 'about 11 hours ago', 'price': '425,000 EGP'}
# (33, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/brilliance/fsv/f480599d49c7459aaaed922b83b622a1', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '122,000 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2014', 'brand': 'Brilliance', 'Model': 'FSV', 'date': 'about 11 hours ago', 'price': '170,000 EGP'}
# (34, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/renault/sandero', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '80,000 KM', 'Color': 'Black', 'Engine Capacity': '1600 CC', 'Fabrica?': 'No', 'Condition': 'Used', 'Year': '2016', 'brand': 'Renault', 'Model': 'Sandero Stepway', 'date': 'about 11 hours ago', 'price': '225,000 EGP'}
# (35, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/chery/tiggo', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '115,000 KM', 'Color': 'Gray', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2019', 'brand': 'Chery', 'Model': 'Tiggo 3', 'date': 'about 11 hours ago', 'price': '350,000 EGP'}
# (36, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/hyundai/elantra', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '159,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2009', 'brand': 'Hyundai', 'Model': 'Elantra HD', 'date': 'about 11 hours ago', 'price': '290,000 EGP'}
# (37, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/renault/sandero', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '110,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2016', 'brand': 'Renault', 'Model': 'Sandero Stepway', 'date': 'about 11 hours ago', 'price': '295,000 EGP'}
# (38, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/skoda/kamiq/9db6d6916b014efebe71c7cdba3709a9', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '50,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2021', 'brand': 'Skoda', 'Model': 'KAMIQ', 'date': 'about 11 hours ago', 'price': '900,000 EGP'}
# (39, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/hyundai/getz/c7fff1528dbf4cfbbb128e9f0c017657', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '240,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2008', 'brand': 'Hyundai', 'Model': 'Getz', 'date': 'about 11 hours ago', 'price': '230,000 EGP'}
# (40, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/renault/clio/1043827881f6423799ede6051e1b0195', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '176,000 KM', 'Color': 'Gray', 'Engine Capacity': '1200 CC', 'Condition': 'Used', 'Year': '2002', 'brand': 'Renault', 'Model': 'Clio', 'date': 'about 12 hours ago', 'price': '75,000 EGP'}
# (41, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/x3/008c26fb345b414eb3b7700315278922', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '190,000 KM', 'Engine Capacity': '3000 CC', 'Condition': 'Used', 'Year': '2009', 'brand': 'BMW', 'Model': 'X3', 'date': 'about 12 hours ago', 'price': '440,000 EGP'}
# (42, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/hyundai/i10/b23d4b524f6c496d96be3c7503749d74', 'Body Shape': 'Hatchback', 'Transmission': 'Manual', 'Mileage': '130,000 KM', 'Engine Capacity': '1100 CC', 'Condition': 'Used', 'Year': '2008', 'brand': 'Hyundai', 'Model': 'I10', 'date': 'about 12 hours ago', 'price': '140,000 EGP'}
# (43, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/hyundai/elantra', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '67,000 KM', 'Color': 'Maroon', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2017', 'brand': 'Hyundai', 'Model': 'Elantra AD', 'date': 'about 12 hours ago', 'price': '505,000 EGP'}
# (44, 14)
#                                                 Ad_ID Body Shape   Color  \
# 43  https://www.contactcars.com/en/usedcars/hyunda...      Sedan  Maroon
#
#    Condition Engine Capacity Fabrica?    Mileage       Model Transmission  \
# 43      Used         1600 CC      Yes  67,000 KM  Elantra AD    Automatic
#
#     Year    brand                date        price In Warranty
# 43  2017  Hyundai  about 12 hours ago  505,000 EGP         NaN
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/citroen/c5', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '28,755 KM', 'Color': 'White', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2020', 'brand': 'Citroen', 'Model': 'C5 Aircross', 'date': '2 days ago', 'price': '930,000 EGP'}
# (45, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mg/5/5a872cef2ad6415e83ca13965a979a8a', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '29,000 KM', 'Color': 'White', 'Engine Capacity': '1500 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2021', 'brand': 'MG', 'Model': '5', 'date': '2 days ago', 'price': '505,000 EGP'}
# (46, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/glc', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '100 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Mercedes', 'Model': 'GLC 200', 'date': '9 days ago', 'price': '3,900,000 EGP'}
# (47, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/jeep/grand', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '87,890 KM', 'Color': 'Gray', 'Engine Capacity': '5700 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2018', 'brand': 'Jeep', 'Model': 'Grand Cherokee', 'date': '26 days ago', 'price': '1,650,000 EGP'}
# (48, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/byd/l3/2583d2697abe42c3bc205245aee49ba0', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '5,200 KM', 'Color': 'Brown', 'Engine Capacity': '1500 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2022', 'brand': 'BYD', 'Model': 'L3', 'date': '28 days ago', 'price': '375,000 EGP'}
# (49, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/byd/f3/63c018012e08d8c7f5c67502', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '72,799 KM', 'Engine Capacity': '1500 CC', 'Fabrica?': 'No', 'Condition': 'Used', 'Year': '2020', 'brand': 'BYD', 'Model': 'F3', 'date': 'about a month ago', 'price': '270,000 EGP'}
# (50, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/420i', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '10 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'BMW', 'Model': '420i Gran Coupe', 'date': '4 days ago', 'price': '700,000 EGP'}
# (51, 14)
# ____________________
# inside exption
# list index out of range
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/porsche/macan/bd7f763cf4bf483d80ad7209b5e672b1', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '13,000 KM', 'Engine Capacity': '2000 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2020', 'brand': 'Porsche', 'Model': 'Macan', 'date': '13 days ago', 'price': '3,150,000 EGP'}
# (52, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/g', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '17,000 KM', 'Engine Capacity': '4000 CC', 'Condition': 'Used', 'Year': '2020', 'brand': 'Mercedes', 'Model': 'G 63', 'date': 'about a month ago', 'price': '3,400,000 EGP'}
# (53, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/x5/33d7e3328f584291a3bc59f7fb6c595b', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '50,000 KM', 'Color': 'Blue', 'Engine Capacity': '4400 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2018', 'brand': 'BMW', 'Model': 'X5', 'date': 'about 15 hours ago', 'price': '2,650,000 EGP'}
# (54, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/hyundai/elantra', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '112,000 KM', 'Color': 'Silver', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2016', 'brand': 'Hyundai', 'Model': 'Elantra MD', 'date': 'about 15 hours ago', 'price': '430,000 EGP'}
# (55, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/ford/fiesta/6a174cd1ea7d4d6ea5cd9e1c42951e59', 'Body Shape': 'Hatchback', 'Transmission': 'Manual', 'Mileage': '150,000 KM', 'Engine Capacity': '1300 CC', 'Condition': 'Used', 'Year': '1998', 'brand': 'Ford', 'Model': 'Fiesta', 'date': 'about 15 hours ago', 'price': '68,000 EGP'}
# (56, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/chevrolet/lanos/be68af9a5cf34335b35f92886dce8689', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '200,000 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2010', 'brand': 'Chevrolet', 'Model': 'Lanos', 'date': 'about 15 hours ago', 'price': '110,000 EGP'}
# (57, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/kia/cerato/40ce5a6111d448e3ba02f8c80d47c80e', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '120,000 KM', 'Color': 'Maroon', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2012', 'brand': 'Kia', 'Model': 'Cerato', 'date': 'about 15 hours ago', 'price': '392,000 EGP'}
# (58, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/nissan', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '65,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2016', 'brand': 'Nissan Motor Egypt', 'Model': 'Juke', 'date': 'about 15 hours ago', 'price': '455,000 EGP'}
# (59, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/ford/fiesta/20a010b6adfc4fc696afb7d937bc7464', 'Body Shape': 'Hatchback', 'Transmission': 'Manual', 'Mileage': '150,000 KM', 'Color': 'Turquoise', 'Engine Capacity': '1000 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2019', 'brand': 'Ford', 'Model': 'Fiesta', 'date': 'about 15 hours ago', 'price': '365,000 EGP'}
# (60, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/audi/a3/4f2860976ea041e4bb21bfac0d2d6f4f', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '1,000 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Audi', 'Model': 'A3', 'date': 'about 15 hours ago', 'price': '1,600,000 EGP'}
# (61, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/nissan', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '80,000 KM', 'Color': 'Brown', 'Engine Capacity': '1200 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2017', 'brand': 'Nissan Motor Egypt', 'Model': 'Qashqai', 'date': 'about 16 hours ago', 'price': '600,000 EGP'}
# (62, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/kia/cerato/0baee29975e849e6b4f231828c266913', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '270,000 KM', 'Color': 'Black', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2014', 'brand': 'Kia', 'Model': 'Cerato', 'date': 'about 16 hours ago', 'price': '435,000 EGP'}
# (63, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/volkswagen/passat/c7433022ddbe41a39fb09ca15b523521', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '276,000 KM', 'Color': 'Black', 'Engine Capacity': '1400 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2012', 'brand': 'Volkswagen', 'Model': 'Passat', 'date': 'about 16 hours ago', 'price': '520,000 EGP'}
# (64, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/renault/sandero', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '115,000 KM', 'Color': 'Blue', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2016', 'brand': 'Renault', 'Model': 'Sandero Stepway', 'date': 'about 16 hours ago', 'price': '300,000 EGP'}
# (65, 14)
#                                                 Ad_ID Body Shape Color  \
# 64  https://www.contactcars.com/en/usedcars/renaul...  Hatchback  Blue
#
#    Condition Engine Capacity Fabrica?     Mileage            Model  \
# 64      Used         1600 CC      Yes  115,000 KM  Sandero Stepway
#
#    Transmission  Year    brand                date        price In Warranty
# 64    Automatic  2016  Renault  about 16 hours ago  300,000 EGP         NaN
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/jac/js4/5e14fbcc0536470cb01494145f8bfdd6', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '8,403 KM', 'Color': 'Red', 'Engine Capacity': '1500 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2022', 'brand': 'JAC', 'Model': 'JS4', 'date': 'about 17 hours ago', 'price': '530,000 EGP'}
# (66, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/audi/a5/9551c6b0ece54461ae937d56a89be50e', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '100 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Audi', 'Model': 'A5', 'date': '9 days ago', 'price': '3,225,000 EGP'}
# (67, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/byd/f3/3abaf9aecdeb48babc8a611b0c470c8b', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '14,397 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'BYD', 'Model': 'F3', 'date': '11 days ago', 'price': '330,000 EGP'}
# (68, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/chevrolet/optra/7dab8345766e4c6fa70fa6688f59c4f8', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '53 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Chevrolet', 'Model': 'Optra', 'date': '11 days ago', 'price': '450,000 EGP'}
# (69, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/jeep/grand', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '87,890 KM', 'Color': 'Gray', 'Engine Capacity': '5700 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2018', 'brand': 'Jeep', 'Model': 'Grand Cherokee', 'date': '26 days ago', 'price': '1,650,000 EGP'}
# (70, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/byd/f3/63c018012e08d8c7f5c67502', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '72,799 KM', 'Engine Capacity': '1500 CC', 'Fabrica?': 'No', 'Condition': 'Used', 'Year': '2020', 'brand': 'BYD', 'Model': 'F3', 'date': 'about a month ago', 'price': '270,000 EGP'}
# (71, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/750', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '10 KM', 'Engine Capacity': '4400 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'BMW', 'Model': '750 Li', 'date': '4 days ago', 'price': '2,200,000 EGP'}
# (72, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/m8', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '10 KM', 'Color': 'Maroon', 'Engine Capacity': '4400 CC', 'Fabrica?': 'Yes', 'In Warranty': 'Yes', 'Condition': 'Used', 'Year': '2022', 'brand': 'BMW', 'Model': 'M8', 'date': '12 days ago', 'price': '3,000,000 EGP'}
# (73, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/430i', 'Body Shape': 'Coupe', 'Transmission': 'Dual Clutch', 'Mileage': '10 KM', 'Color': 'White', 'Engine Capacity': '2000 CC', 'Fabrica?': 'Yes', 'In Warranty': 'Yes', 'Condition': 'Used', 'Year': '2022', 'brand': 'BMW', 'Model': '430i Coupe', 'date': '12 days ago', 'price': '900,000 EGP'}
# (74, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/e200/10ca54b349a34fdbbd827d16bf4f4147', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '55,000 KM', 'Color': 'Gray', 'Engine Capacity': '2000 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2020', 'brand': 'Mercedes', 'Model': 'E200', 'date': '13 days ago', 'price': '2,325,000 EGP'}
# (75, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/toyota/corolla/6e7ab4481e164544b82c4ac80b560cf2', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '154,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2009', 'brand': 'Toyota', 'Model': 'Corolla', 'date': 'about 18 hours ago', 'price': '250,000 EGP'}
# (76, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/chevrolet/aveo/b4ce7defb2114ed19e348af215c11ec9', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '95,000 KM', 'Color': 'Navy Blue', 'Engine Capacity': '1500 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2014', 'brand': 'Chevrolet', 'Model': 'Aveo', 'date': 'about 18 hours ago', 'price': '233,000 EGP'}
# (77, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/renault/logan/e85954e8ba92411489f1ec0c99b945c2', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '230,000 KM', 'Color': 'Red', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2016', 'brand': 'Renault', 'Model': 'Logan', 'date': 'about 18 hours ago', 'price': '225,000 EGP'}
# (78, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mitsubishi/lancer/55c095738b0e46ef8040ac689b15c8bd', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '80,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2007', 'brand': 'Mitsubishi', 'Model': 'Lancer', 'date': 'about 18 hours ago', 'price': '293,000 EGP'}
# (79, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/renault/duster/fe844dc09b8641988b65b005181a2fa9', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '95,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2020', 'brand': 'Renault', 'Model': 'Duster', 'date': 'about 18 hours ago', 'price': '520,000 EGP'}
# (80, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/renault/duster/a4f92558117b4b7aa662f3fc7a144695', 'Body Shape': 'SUV', 'Transmission': 'CVT', 'Mileage': '52,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2021', 'brand': 'Renault', 'Model': 'Duster', 'date': 'about 18 hours ago', 'price': '585,000 EGP'}
# (81, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/kia/sportage/bc877a2ad2874ad9a1a44378b1bc23af', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '1,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Kia', 'Model': 'Sportage', 'date': 'about 18 hours ago', 'price': '1,550,000 EGP'}
# (82, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/nissan', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '63,000 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2021', 'brand': 'Nissan Motor Egypt', 'Model': 'Sunny', 'date': 'about 18 hours ago', 'price': '335,000 EGP'}
# (83, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/geely/emgrand', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '220,000 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2015', 'brand': 'Geely', 'Model': 'Emgrand 7', 'date': 'about 18 hours ago', 'price': '175,000 EGP'}
# (84, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/peugeot/3008/0762a830950c4a159048e864332640f9', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '160,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2019', 'brand': 'Peugeot', 'Model': '3008', 'date': 'about 18 hours ago', 'price': '800,000 EGP'}
# (85, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/volkswagen/jetta/def2edb5aefc473f841a542e47818865', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '70,000 KM', 'Color': 'Red', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2011', 'brand': 'Volkswagen', 'Model': 'Jetta', 'date': 'about 18 hours ago', 'price': '520,000 EGP'}
# (86, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/nissan', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '195,000 KM', 'Color': 'Red', 'Engine Capacity': '1500 CC', 'Fabrica?': 'No', 'Condition': 'Used', 'Year': '2018', 'brand': 'Nissan Motor Egypt', 'Model': 'Sunny', 'date': 'about 18 hours ago', 'price': '295,000 EGP'}
# (87, 14)
#                                              Ad_ID Body Shape Color Condition  \
# 86  https://www.contactcars.com/en/usedcars/nissan      Sedan   Red      Used
#
#    Engine Capacity Fabrica?     Mileage  Model Transmission  Year  \
# 86         1500 CC       No  195,000 KM  Sunny    Automatic  2018
#
#                  brand                date        price In Warranty
# 86  Nissan Motor Egypt  about 18 hours ago  295,000 EGP         NaN
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mg/5/5a872cef2ad6415e83ca13965a979a8a', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '29,000 KM', 'Color': 'White', 'Engine Capacity': '1500 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2021', 'brand': 'MG', 'Model': '5', 'date': '2 days ago', 'price': '505,000 EGP'}
# (88, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/fiat/500x/33ce8194484d499a9f4f5bcd2114ae43', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '125,360 KM', 'Color': 'Dark Grey', 'Engine Capacity': '1400 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2019', 'brand': 'Fiat', 'Model': '500X', 'date': '8 days ago', 'price': '530,000 EGP'}
# (89, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/volkswagen/tiguan/911c94081e574fccb5403a5678b924cf', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '100 KM', 'Engine Capacity': '1400 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Volkswagen', 'Model': 'Tiguan', 'date': '9 days ago', 'price': '1,730,000 EGP'}
# (90, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/glc', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '100 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Mercedes', 'Model': 'GLC 200', 'date': '9 days ago', 'price': '3,900,000 EGP'}
# (91, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/tesla/model', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '4,000 KM', 'Color': 'Black', 'Engine Capacity': '2000 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2022', 'brand': 'Tesla', 'Model': 'Model Y', 'date': '26 days ago', 'price': '2,050,000 EGP'}
# (92, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/chery/arrizo', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '11,191 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'Chery', 'Model': 'ARRIZO 5', 'date': 'about a month ago', 'price': '395,000 EGP'}
# (93, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/m5/60f031ab7469413f8c99df36a6d7a4bc', 'Body Shape': 'Sedan', 'Transmission': 'Dual Clutch', 'Mileage': '10 KM', 'Color': 'Blue', 'Engine Capacity': '4400 CC', 'Fabrica?': 'Yes', 'In Warranty': 'Yes', 'Condition': 'Used', 'Year': '2022', 'brand': 'BMW', 'Model': 'M5', 'date': '12 days ago', 'price': '2,400,000 EGP'}
# (94, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/m850i/d1a40ecb51444af6a09fda3baa8def20', 'Body Shape': 'Sedan', 'Transmission': 'Dual Clutch', 'Mileage': '10 KM', 'Color': 'Dark Grey', 'Engine Capacity': '4400 CC', 'Fabrica?': 'Yes', 'In Warranty': 'Yes', 'Condition': 'Used', 'Year': '2022', 'brand': 'BMW', 'Model': 'M850i', 'date': '12 days ago', 'price': '1,800,000 EGP'}
# (95, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/g', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '17,000 KM', 'Engine Capacity': '4000 CC', 'Condition': 'Used', 'Year': '2020', 'brand': 'Mercedes', 'Model': 'G 63', 'date': 'about a month ago', 'price': '3,400,000 EGP'}
# (96, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/c180/ca026b07fd0548179469a698b9362267', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '155,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2013', 'brand': 'Mercedes', 'Model': 'C180', 'date': '9 days ago', 'price': '760,000 EGP'}
# (97, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/toyota/corolla/45c17b0f1cd440d5911492751d5060f5', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '13,000 KM', 'Color': 'Baby Blue', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2021', 'brand': 'Toyota', 'Model': 'Corolla', 'date': 'about 19 hours ago', 'price': '860,000 EGP'}
# (98, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/skoda/octavia/506275b0f0924ae99d0d9ac8ac2df111', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '180,000 KM', 'Color': 'Navy Blue', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2002', 'brand': 'Skoda', 'Model': 'Octavia', 'date': 'about 19 hours ago', 'price': '255,000 EGP'}
# (99, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/nissan', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '135,000 KM', 'Color': 'Navy Blue', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2012', 'brand': 'Nissan Motor Egypt', 'Model': 'Qashqai', 'date': 'about 19 hours ago', 'price': '345,000 EGP'}
# (100, 14)
# ____________________
# inside exption
# list index out of range
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/hyundai/accent', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '1,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Hyundai', 'Model': 'Accent RB', 'date': 'about 19 hours ago', 'price': '560,000 EGP'}
# (101, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/opel/astra/00cbeb38c9a64b07bda642a98952f907', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '126,000 KM', 'Color': 'Brown', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2016', 'brand': 'Opel', 'Model': 'Astra', 'date': 'about 19 hours ago', 'price': '420,000 EGP'}
# (102, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mitsubishi/lancer/47f663b230fc410fabba392d96db2e8b', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '152,000 KM', 'Color': 'Silver', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2015', 'brand': 'Mitsubishi', 'Model': 'Lancer', 'date': 'about 19 hours ago', 'price': '380,000 EGP'}
# (103, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/nissan', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '156,000 KM', 'Color': 'Red', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2014', 'brand': 'Nissan Motor Egypt', 'Model': 'Sunny', 'date': 'about 19 hours ago', 'price': '220,000 EGP'}
# (104, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/kia/rio/4b489f0105204eddb54c7a17615234f7', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '112,000 KM', 'Color': 'Red', 'Engine Capacity': '1400 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2014', 'brand': 'Kia', 'Model': 'Rio', 'date': 'about 19 hours ago', 'price': '380,000 EGP'}
# (105, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/renault/scala/1bc1cc281a534f768faf94ff5d395574', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '189,000 KM', 'Color': 'Silver', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2010', 'brand': 'Renault', 'Model': 'Scala', 'date': 'about 19 hours ago', 'price': '225,000 EGP'}
# (106, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mg/5/587743e46b8d4135842ade2e95bf1071', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '1,000 KM', 'Color': 'Blue', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'MG', 'Model': '5', 'date': 'about 19 hours ago', 'price': '590,000 EGP'}
# (107, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/toyota/corolla/b91a8a7885ea44bb848981bf64e22bc0', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '80,000 KM', 'Color': 'Silver', 'Engine Capacity': '1300 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2006', 'brand': 'Toyota', 'Model': 'Corolla', 'date': 'about 19 hours ago', 'price': '370,000 EGP'}
# (108, 14)
#                                                  Ad_ID Body Shape   Color  \
# 107  https://www.contactcars.com/en/usedcars/toyota...      Sedan  Silver
#
#     Condition Engine Capacity Fabrica?    Mileage    Model Transmission  Year  \
# 107      Used         1300 CC      Yes  80,000 KM  Corolla       Manual  2006
#
#       brand                date        price In Warranty
# 107  Toyota  about 19 hours ago  370,000 EGP         NaN
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/fiat/500x/33ce8194484d499a9f4f5bcd2114ae43', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '125,360 KM', 'Color': 'Dark Grey', 'Engine Capacity': '1400 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2019', 'brand': 'Fiat', 'Model': '500X', 'date': '8 days ago', 'price': '530,000 EGP'}
# (109, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/opel/grand', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '44,270 KM', 'Color': 'Maroon', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2021', 'brand': 'Opel', 'Model': 'Grand Land', 'date': '8 days ago', 'price': '930,000 EGP'}
# (110, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/volkswagen/golf/16ca78db11a64a5f95b53e61bb6f8331', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '100 KM', 'Engine Capacity': '1200 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Volkswagen', 'Model': 'Golf', 'date': '9 days ago', 'price': '1,950,000 EGP'}
# (111, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/eqs/06701e9061c042b48b9ca73317c5ee79', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '100 KM', 'Engine Capacity': '6400 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Mercedes', 'Model': 'EQS', 'date': '9 days ago', 'price': '5,200,000 EGP'}
# (112, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/nissan', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '44,566 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2020', 'brand': 'Nissan Motor Egypt', 'Model': 'Sunny', 'date': '11 days ago', 'price': '365,000 EGP'}
# (113, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/byd/f3/3abaf9aecdeb48babc8a611b0c470c8b', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '14,397 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'BYD', 'Model': 'F3', 'date': '11 days ago', 'price': '330,000 EGP'}
# (114, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/440i', 'Body Shape': 'Cabriolet', 'Transmission': 'Automatic', 'Mileage': '10 KM', 'Engine Capacity': '3000 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'BMW', 'Model': '440i convertible', 'date': '4 days ago', 'price': '1,100,000 EGP'}
# (115, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/gt63/63bd6388b1162b5d94406424', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '4,000 KM', 'Color': 'White', 'Engine Capacity': '3000 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2019', 'brand': 'Mercedes', 'Model': 'GT63', 'date': 'about a month ago', 'price': '2,140,000 EGP'}
# (116, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/jeep/renegade/3390e61ff86f4679a31d0bc0af438a06', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '38,000 KM', 'Color': 'White', 'Engine Capacity': '1400 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2020', 'brand': 'Jeep', 'Model': 'Renegade', 'date': '4 days ago', 'price': '910,000 EGP'}
# (117, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/cla', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '14,000 KM', 'Engine Capacity': '1300 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'Mercedes', 'Model': 'CLA 200', 'date': '8 days ago', 'price': '2,000,000 EGP'}
# (118, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mitsubishi/lancer/ef553cf9480b496d8aca0f5dd12b6e61', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '134,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2008', 'brand': 'Mitsubishi', 'Model': 'Lancer', 'date': 'about 20 hours ago', 'price': '220,000 EGP'}
# (119, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/e200/5a22493c556340deb12263bb9fb7c0fe', 'Body Shape': 'Coupe', 'Transmission': 'Dual Clutch', 'Mileage': '1,000 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'Mercedes', 'Model': 'E200', 'date': 'about 21 hours ago', 'price': '3,300,000 EGP'}
# (120, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/kia/xceed/ab76e2e11666447cb23a54a784fd1e62', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '1,000 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'Kia', 'Model': 'Xceed', 'date': 'about 21 hours ago', 'price': '930,000 EGP'}
# (121, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/opel/insignia/01793b1c69cb414f9264de59f77b4c0a', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '101,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2015', 'brand': 'Opel', 'Model': 'Insignia', 'date': 'about 21 hours ago', 'price': '610,000 EGP'}
# (122, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '1,000 KM', 'Engine Capacity': '800 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'Mercedes', 'Model': 'EQE 43', 'date': 'about 21 hours ago', 'price': '3,680,000 EGP'}
# (123, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/renault/fluence/121881829d804082897e8c15c4ac83b5', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '150,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2013', 'brand': 'Renault', 'Model': 'Fluence', 'date': 'about 21 hours ago', 'price': '340,000 EGP'}
# (124, 14)
# ____________________
# ...
# (6028, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/porsche/macan/d451d6c0de8b43dfbe9fb12b20ea9d56', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '76,000 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '2021', 'brand': 'Porsche', 'Model': 'Macan', 'date': '27 days ago', 'price': '2,500,000 EGP'}
# (6029, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/s350/3e9f9f7a481d4489ad917649af0746f6', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '160,000 KM', 'Engine Capacity': '3500 CC', 'Condition': 'Used', 'Year': '2009', 'brand': 'Mercedes', 'Model': 'S350', 'date': '27 days ago', 'price': '1,100,000 EGP'}
# (6030, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/hyundai/i10/db4f4b73f84b4380b1511bbf3b8c75a6', 'Body Shape': 'Hatchback', 'Transmission': 'Manual', 'Mileage': '226,000 KM', 'Color': 'Silver', 'Engine Capacity': '1200 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2011', 'brand': 'Hyundai', 'Model': 'I10', 'date': '27 days ago', 'price': '155,000 EGP'}
# (6031, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/toyota/cressida/23c7c55814fb45af838f365b2363ab91', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '277,000 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '1983', 'brand': 'Toyota', 'Model': 'Cressida', 'date': '27 days ago', 'price': '50,000 EGP'}
# (6032, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/honda/city/9f67c1a2d40d427f8f9e84dc05801544', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '150,000 KM', 'Color': 'Maroon', 'Engine Capacity': '1500 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2016', 'brand': 'Honda', 'Model': 'City', 'date': '27 days ago', 'price': '408,000 EGP'}
# (6033, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/nissan', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '52,000 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'Nissan Motor Egypt', 'Model': 'Sunny', 'date': '27 days ago', 'price': '380,000 EGP'}
# (6034, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/chevrolet/optra/a2ebd9aeff4e4d5cbae530fd9187d05c', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '136,500 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2018', 'brand': 'Chevrolet', 'Model': 'Optra', 'date': '27 days ago', 'price': '320,000 EGP'}
# (6035, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/range', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '1,170 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'Range Rover', 'Model': 'Velar', 'date': '27 days ago', 'price': '3,150,000 EGP'}
# (6036, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/renault/megane/c35de82253364bfcbbd7606722a32ef2', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '60,000 KM', 'Color': 'Bronze', 'Engine Capacity': '1200 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2021', 'brand': 'Renault', 'Model': 'Megane', 'date': '9 days ago', 'price': '730,000 EGP'}
# (6037, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/volkswagen/tiguan/911c94081e574fccb5403a5678b924cf', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '100 KM', 'Engine Capacity': '1400 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Volkswagen', 'Model': 'Tiguan', 'date': '9 days ago', 'price': '1,730,000 EGP'}
# (6038, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/volkswagen/golf/16ca78db11a64a5f95b53e61bb6f8331', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '100 KM', 'Engine Capacity': '1200 CC', 'Condition': 'Used', 'Year': '2023', 'brand': 'Volkswagen', 'Model': 'Golf', 'date': '9 days ago', 'price': '1,950,000 EGP'}
# (6039, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/chevrolet/optra/63c02c23161daf55d5265d1d', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '100,827 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2021', 'brand': 'Chevrolet', 'Model': 'Optra', 'date': 'about a month ago', 'price': '370,000 EGP'}
# (6040, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/hyundai/elantra', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '75,525 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2020', 'brand': 'Hyundai', 'Model': 'Elantra HD', 'date': 'about a month ago', 'price': '460,000 EGP'}
# (6041, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/byd/f3/63c0134c1c16df2ee446f6cc', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '90,717 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2020', 'brand': 'BYD', 'Model': 'F3', 'date': 'about a month ago', 'price': '270,000 EGP'}
# (6042, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/bmw/430i', 'Body Shape': 'Coupe', 'Transmission': 'Dual Clutch', 'Mileage': '10 KM', 'Color': 'Dark Grey', 'Engine Capacity': '2000 CC', 'Fabrica?': 'Yes', 'In Warranty': 'Yes', 'Condition': 'Used', 'Year': '2022', 'brand': 'BMW', 'Model': '430i Coupe', 'date': '12 days ago', 'price': '900,000 EGP'}
# (6043, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/porsche/macan/bd7f763cf4bf483d80ad7209b5e672b1', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '13,000 KM', 'Engine Capacity': '2000 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2020', 'brand': 'Porsche', 'Model': 'Macan', 'date': '13 days ago', 'price': '3,150,000 EGP'}
# (6044, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/mercedes/c180/63a98ce7d464dfb4ae772ff7', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '10 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'Mercedes', 'Model': 'C180', 'date': '2 months ago', 'price': '2,325,000 EGP'}
# (6045, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/opel/grand', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '20,500 KM', 'Color': 'Blue', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2021', 'brand': 'Opel', 'Model': 'Grand Land', 'date': '22 days ago', 'price': '285,000 EGP'}
# (6046, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/renault/sandero/dcce0c39c080470abd5c0dcda0f6dc50', 'Body Shape': 'Hatchback', 'Transmission': 'Manual', 'Mileage': '187,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2014', 'brand': 'Renault', 'Model': 'Sandero', 'date': '27 days ago', 'price': '160,000 EGP'}
# (6047, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/hyundai/tucson/5d9ae71d122443c3b0379ead346a26be', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '50,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2018', 'brand': 'Hyundai', 'Model': 'Tucson', 'date': '27 days ago', 'price': '760,000 EGP'}
# (6048, 14)
# ____________________
# inside exption
# list index out of range
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/peugeot/508/cf95f52363764800a932d7b280c40745', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '88,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2020', 'brand': 'Peugeot', 'Model': '508', 'date': '27 days ago', 'price': '870,000 EGP'}
# (6049, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/skoda/octavia/e9332034b3344b508fca6e5c78cb3fdc', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '20,000 KM', 'Engine Capacity': '2000 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'Skoda', 'Model': 'Octavia', 'date': '27 days ago', 'price': '1,400,000 EGP'}
# (6050, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/renault/kadjar/9e3220547c73477ab06d84c6e1df285d', 'Body Shape': 'SUV', 'Transmission': 'Automatic', 'Mileage': '156,000 KM', 'Color': 'White', 'Engine Capacity': '1200 CC', 'Fabrica?': 'No', 'Condition': 'Used', 'Year': '2017', 'brand': 'Renault', 'Model': 'Kadjar', 'date': '27 days ago', 'price': '525,000 EGP'}
# (6051, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/chevrolet/cruze/44b067b3704c4f0a9acc432d3aac4ef9', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '180,000 KM', 'Color': 'Gray', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2012', 'brand': 'Chevrolet', 'Model': 'Cruze', 'date': '27 days ago', 'price': '248,500 EGP'}
# (6052, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/fiat/grand', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '111,000 KM', 'Color': 'Black', 'Engine Capacity': '1400 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2016', 'brand': 'Fiat', 'Model': 'Grand Punto', 'date': '27 days ago', 'price': '330,000 EGP'}
# (6053, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/chery/tiggo', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '22,000 KM', 'Color': 'Silver', 'Engine Capacity': '1600 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2020', 'brand': 'Chery', 'Model': 'Tiggo 3', 'date': '27 days ago', 'price': '3,950,000 EGP'}
# (6054, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/kia/picanto/347ee621c83f4cf1bb55413d354c1bbe', 'Body Shape': 'Hatchback', 'Transmission': 'Automatic', 'Mileage': '135,000 KM', 'Color': 'Silver', 'Engine Capacity': '1300 CC', 'Fabrica?': 'Yes', 'Condition': 'Used', 'Year': '2017', 'brand': 'Kia', 'Model': 'Picanto', 'date': '27 days ago', 'price': '325,000 EGP'}
# (6055, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/geely/emgrand', 'Body Shape': 'Sedan', 'Transmission': 'Manual', 'Mileage': '300,000 KM', 'Engine Capacity': '1500 CC', 'Condition': 'Used', 'Year': '2015', 'brand': 'Geely', 'Model': 'Emgrand 7', 'date': '27 days ago', 'price': '130,000 EGP'}
# (6056, 14)
# ____________________
# {'Ad_ID': 'https://www.contactcars.com/en/usedcars/fiat/tipo/11fb53d986454f0e9a509970f8ae2b70', 'Body Shape': 'Sedan', 'Transmission': 'Automatic', 'Mileage': '26,000 KM', 'Engine Capacity': '1600 CC', 'Condition': 'Used', 'Year': '2022', 'brand': 'Fiat', 'Model': 'Tipo', 'date': '27 days ago', 'price': '600,000 EGP'}
# (6057, 14)
#                                                   Ad_ID Body Shape Color  \
# 6056  https://www.contactcars.com/en/usedcars/fiat/t...      Sedan   NaN
#
#      Condition Engine Capacity Fabrica?    Mileage Model Transmission  Year  \
# 6056      Used         1600 CC      NaN  26,000 KM  Tipo    Automatic  2022
#
#      brand         date        price In Warranty
# 6056  Fiat  27 days ago  600,000 EGP         NaN
#                                                   Ad_ID Body Shape Color  \
# 6056  https://www.contactcars.com/en/usedcars/fiat/t...      Sedan   NaN
#
#      Condition Engine Capacity Fabrica?    Mileage Model Transmission  Year  \
# 6056      Used         1600 CC      NaN  26,000 KM  Tipo    Automatic  2022
#
#      brand         date        price In Warranty
# 6056  Fiat  27 days ago  600,000 EGP         NaN
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-38-6997e622a582> in <module>
#       6         sleep(5)
#       7
# ----> 8     links_list =  get_links_list(get_page_link(i), chrome)
#       9
#      10     try:
#
# <ipython-input-37-a479aa93e189> in get_links_list(link, driver)
#       1 def get_links_list(link, driver):
#       2
# ----> 3     driver.get(link)
#       4     scroll_down(driver)
#       5 #     z = chrome.find_elements_by_css_selector("d-block bg--white car-link")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     435         Loads a web page in the current browser session.
#     436         """
# --> 437         self.execute(Command.GET, {'url': url})
#     438
#     439     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=110.0.5481.100)
# Stacktrace:
# 0   chromedriver                        0x000000010e4fc138 chromedriver + 4923704
# 1   chromedriver                        0x000000010e4749d3 chromedriver + 4368851
# 2   chromedriver                        0x000000010e0bd787 chromedriver + 472967
# 3   chromedriver                        0x000000010e0b5235 chromedriver + 438837
# 4   chromedriver                        0x000000010e0a69fc chromedriver + 379388
# 5   chromedriver                        0x000000010e0a84f6 chromedriver + 386294
# 6   chromedriver                        0x000000010e0a6dc0 chromedriver + 380352
# 7   chromedriver                        0x000000010e0a5a11 chromedriver + 375313
# 8   chromedriver                        0x000000010e0a587b chromedriver + 374907
# 9   chromedriver                        0x000000010e0a40c6 chromedriver + 368838
# 10  chromedriver                        0x000000010e0a447d chromedriver + 369789
# 11  chromedriver                        0x000000010e0bfaf8 chromedriver + 482040
# 12  chromedriver                        0x000000010e1462a1 chromedriver + 1032865
# 13  chromedriver                        0x000000010e12afb2 chromedriver + 921522
# 14  chromedriver                        0x000000010e145c0f chromedriver + 1031183
# 15  chromedriver                        0x000000010e12ad23 chromedriver + 920867
# 16  chromedriver                        0x000000010e0f1a4b chromedriver + 686667
# 17  chromedriver                        0x000000010e0f3044 chromedriver + 692292
# 18  chromedriver                        0x000000010e4c78fe chromedriver + 4708606
# 19  chromedriver                        0x000000010e4cce22 chromedriver + 4730402
# 20  chromedriver                        0x000000010e4d56bf chromedriver + 4765375
# 21  chromedriver                        0x000000010e4cde80 chromedriver + 4734592
# 22  chromedriver                        0x000000010e49e975 chromedriver + 4540789
# 23  chromedriver                        0x000000010e4efe78 chromedriver + 4873848
# 24  chromedriver                        0x000000010e4efff5 chromedriver + 4874229
# 25  chromedriver                        0x000000010e5046de chromedriver + 4957918
# 26  libsystem_pthread.dylib             0x00007fff76e7d2eb _pthread_body + 126
# 27  libsystem_pthread.dylib             0x00007fff76e80249 _pthread_start + 66
# 28  libsystem_pthread.dylib             0x00007fff76e7c40d thread_start + 13

# %%
df.columns
# Out:
# Index(['Ad_ID', 'Body Shape', 'Color', 'Condition', 'Engine Capacity',
#        'Fabrica?', 'Mileage', 'Model', 'Transmission', 'Year', 'brand', 'date',
#        'price', 'In Warranty'],
#       dtype='object')

# %%
df.rename(inplace=True, columns={"Body Shape":"Body Type",
                                 "Engine Capacity":"Engine Capacity (CC)",
                                "Transmission":"Transmission Type"
                                ,"Mileage":"Kilometers"
                                })
df.columns
# Out:
# Index(['Ad_ID', 'Body Type', 'Color', 'Condition', 'Engine Capacity (CC)',
#        'Fabrica?', 'Kilometers', 'Model', 'Transmission Type', 'Year', 'brand',
#        'date', 'price', 'In Warranty'],
#       dtype='object')

# %%
df = df[["Ad_ID","date","brand","Model","Year","Condition","Kilometers", "Engine Capacity (CC)", "Transmission Type","Body Type","Fabrica?","price"]]
df[100:250]
# Out:
#                                                  Ad_ID                date  \
# 100  https://www.contactcars.com/en/usedcars/hyunda...  about 19 hours ago
# 101  https://www.contactcars.com/en/usedcars/opel/a...  about 19 hours ago
# 102  https://www.contactcars.com/en/usedcars/mitsub...  about 19 hours ago
# 103     https://www.contactcars.com/en/usedcars/nissan  about 19 hours ago
# 104  https://www.contactcars.com/en/usedcars/kia/ri...  about 19 hours ago
# ..                                                 ...                 ...
# 245   https://www.contactcars.com/en/usedcars/volvo/xc        2 months ago
# 246  https://www.contactcars.com/en/usedcars/merced...        2 months ago
# 247   https://www.contactcars.com/en/usedcars/volvo/xc          5 days ago
# 248  https://www.contactcars.com/en/usedcars/opel/a...          2 days ago
# 249  https://www.contactcars.com/en/usedcars/skoda/...          2 days ago
#
#                   brand      Model  Year Condition  Kilometers  \
# 100             Hyundai  Accent RB  2023      Used    1,000 KM
# 101                Opel      Astra  2016      Used  126,000 KM
# 102          Mitsubishi     Lancer  2015      Used  152,000 KM
# 103  Nissan Motor Egypt      Sunny  2014      Used  156,000 KM
# 104                 Kia        Rio  2014      Used  112,000 KM
# ..                  ...        ...   ...       ...         ...
# 245               Volvo      XC 90  2021      Used   16,000 KM
# 246            Mercedes       C180  2022      Used       10 KM
# 247               Volvo      XC 60  2022      Used   17,500 KM
# 248                Opel      Astra  2021      Used   55,000 KM
# 249               Skoda    Octavia  2021      Used   78,000 KM
#
#     Engine Capacity (CC) Transmission Type  Body Type Fabrica?          price
# 100              1600 CC         Automatic      Sedan      NaN    560,000 EGP
# 101              1600 CC         Automatic      Sedan      Yes    420,000 EGP
# 102              1600 CC         Automatic      Sedan      Yes    380,000 EGP
# 103              1500 CC         Automatic      Sedan      NaN    220,000 EGP
# 104              1400 CC         Automatic  Hatchback      Yes    380,000 EGP
# ..                   ...               ...        ...      ...            ...
# 245              2000 CC         Automatic        SUV      NaN  1,180,000 EGP
# 246              1500 CC         Automatic      Sedan      NaN  2,325,000 EGP
# 247              2000 CC         Automatic        SUV      NaN  1,950,000 EGP
# 248              1400 CC         Automatic      Sedan      NaN    495,000 EGP
# 249              1400 CC         Automatic      Sedan      Yes    970,000 EGP
#
# [150 rows x 12 columns]

# %%
import datetime

date = datetime.datetime.now().date().strftime("%d%m%Y")

df.to_csv("contact_cars2.csv"+ date)
df.shape
# Out:
# (6057, 12)

# %%
chrome.quit

# %%
df["Ad_ID"] = df.loc[:, "Ad_ID"].apply(lambda x: x.split("/")[-1])

# %%
str(datetime.datetime.now().date().strftime("%d%m%Y"))
(datetime.datetime.now().date() - datetime.timedelta(20)).strftime("%d%m%Y")
# Out:
# '29012023'

# %%
dt = "20 days ago"
# dt = 'about 16 hours ago'


print(correct_date(dt))
# Out:
# 29-01-2023

# %%
df["date"].unique()
# Out:
# array(['about 16 hours ago', '9 days ago', '11 days ago', '12 days ago',
#        '2 months ago', '4 days ago', '15 days ago', 'about an hour ago',
#        'about 2 hours ago', 'about 3 hours ago', 'about 5 hours ago',
#        'about 6 hours ago', '5 days ago', '8 days ago',
#        'about a month ago', 'about 11 hours ago', 'about 12 hours ago',
#        '2 days ago', '26 days ago', '28 days ago', '13 days ago',
#        'about 15 hours ago', 'about 17 hours ago', 'about 18 hours ago',
#        'about 19 hours ago', 'about 20 hours ago', 'about 21 hours ago',
#        '10 days ago', 'about 22 hours ago', 'about 23 hours ago',
#        'a day ago', '23 days ago', 'Cairo', '3 days ago', '6 days ago',
#        '22 days ago', '7 days ago', 'about 24 hours ago', '14 days ago',
#        '44 minutes ago', '16 days ago', '17 days ago', '18 days ago',
#        '19 days ago', '20 days ago', '21 days ago', 'about 4 hours ago',
#        '24 days ago', '25 days ago', 'about 7 hours ago',
#        'about 8 hours ago', '27 days ago'], dtype=object)
